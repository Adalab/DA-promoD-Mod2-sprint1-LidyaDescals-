# %%
import pandas as pd

# %%
df = pd.read_csv("spotify_youtube.csv", index_col = 0)
pd.options.display.max_columns = None

# %%
df[df["Album"] == "Hamilton (Original Broadway Cast Recording)"]
# Out:
#                                    Artist  \
# 13779                  Lin-Manuel Miranda
# 13780                  Lin-Manuel Miranda
# 13781                  Lin-Manuel Miranda
# 13782                  Lin-Manuel Miranda
# 13783                  Lin-Manuel Miranda
# 13785                  Lin-Manuel Miranda
# 13786                  Lin-Manuel Miranda
# 13787                  Lin-Manuel Miranda
# 13788                  Lin-Manuel Miranda
# 15768                     Leslie Odom Jr.
# 15769                     Leslie Odom Jr.
# 15770                     Leslie Odom Jr.
# 15771                     Leslie Odom Jr.
# 15772                     Leslie Odom Jr.
# 15773                     Leslie Odom Jr.
# 15774                     Leslie Odom Jr.
# 15775                     Leslie Odom Jr.
# 15776                     Leslie Odom Jr.
# 15777                     Leslie Odom Jr.
# 18418  Original Broadway Cast of Hamilton
# 18419  Original Broadway Cast of Hamilton
# ...
